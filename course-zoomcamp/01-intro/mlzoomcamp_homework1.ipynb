# %% [markdown]
# ## Importing libraries

# %%
import requests

# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# ## Importing data using pandas

# %%
url = 'https://raw.githubusercontent.com/alexeygrigorev/mlbookcamp-code/master/chapter-02-car-price/data.csv'
res = requests.get(url, allow_redirects=True)
with open('car_price_data.csv','wb') as file:
    file.write(res.content)
price_data = pd.read_csv('car_price_data.csv')

# %%
price_data.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %% [markdown]
# ## checking version of libraries and shape of dataframe

# %%
price_data.shape
# Out:
# (11914, 16)

# %%
np.__version__
# Out:
# '1.21.2'

# %%
pd.__version__
# Out:
# '1.3.2'

# %%
avg_price = price_data['MSRP'].mean()
print(avg_price)
# Out:
# 40594.737032063116

# %%
include =['object', 'float', 'int']

# %%
price_data.describe().round(2)
# Out:
#            Year  Engine HP  Engine Cylinders  Number of Doors  highway MPG  \
# count  11914.00   11845.00          11884.00         11908.00     11914.00
# mean    2010.38     249.39              5.63             3.44        26.64
# std        7.58     109.19              1.78             0.88         8.86
# min     1990.00      55.00              0.00             2.00        12.00
# 25%     2007.00     170.00              4.00             2.00        22.00
# 50%     2015.00     227.00              6.00             4.00        26.00
# 75%     2016.00     300.00              6.00             4.00        30.00
# max     2017.00    1001.00             16.00             4.00       354.00
#
#        city mpg  Popularity        MSRP
# count  11914.00    11914.00    11914.00
# mean      19.73     1554.91    40594.74
# std        8.99     1441.86    60109.10
# min        7.00        2.00     2000.00
# 25%       16.00      549.00    21000.00
# 50%       18.00     1385.00    29995.00
# ...

# %%
price_data.nunique()
# Out:
# Make                   48
# Model                 915
# Year                   28
# Engine Fuel Type       10
# Engine HP             356
# Engine Cylinders        9
# Transmission Type       5
# Driven_Wheels           4
# Number of Doors         3
# Market Category        71
# Vehicle Size            3
# Vehicle Style          16
# highway MPG            59
# city mpg               69
# Popularity             48
# MSRP                 6049
# dtype: int64

# %%
price_data.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
price_data.groupby('Make').MSRP.mean().round(2)
# Out:
# Make
# Acura              34887.59
# Alfa Romeo         61600.00
# Aston Martin      197910.38
# Audi               53452.11
# BMW                61546.76
# Bentley           247169.32
# Bugatti          1757223.67
# Buick              28206.61
# Cadillac           56231.32
# Chevrolet          28350.39
# Chrysler           26722.96
# Dodge              22390.06
# FIAT               22670.24
# Ferrari           238218.84
# Ford               27399.27
# GMC                30493.30
# Genesis            46616.67
# HUMMER             36464.41
# Honda              26674.34
# Hyundai            24597.04
# Infiniti           42394.21
# Kia                25310.17
# Lamborghini       331567.31
# Land Rover         67823.22
# Lexus              47549.07
# Lincoln            42839.83
# Lotus              69188.28
# Maserati          114207.71
# Maybach           546221.88
# Mazda              20039.38
# McLaren           239805.00
# Mercedes-Benz      71476.23
# Mitsubishi         21240.54
# ...

# %%
year_2015 = price_data[price_data["Year"] >= 2015]

# %%
year_2015.head()
# Out:
#     Make       Model  Year                Engine Fuel Type  Engine HP  \
# 32  FIAT  124 Spider  2017  premium unleaded (recommended)      160.0
# 33  FIAT  124 Spider  2017  premium unleaded (recommended)      160.0
# 34  FIAT  124 Spider  2017  premium unleaded (recommended)      160.0
# 41   BMW    2 Series  2016     premium unleaded (required)      240.0
# 42   BMW    2 Series  2016     premium unleaded (required)      240.0
#
#     Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 32               4.0            MANUAL  rear wheel drive              2.0
# 33               4.0            MANUAL  rear wheel drive              2.0
# 34               4.0            MANUAL  rear wheel drive              2.0
# 41               4.0         AUTOMATIC  rear wheel drive              2.0
# 42               4.0         AUTOMATIC  rear wheel drive              2.0
#
#        Market Category Vehicle Size Vehicle Style  highway MPG  city mpg  \
# ...

# %%
year_2015.shape
# Out:
# (5995, 16)

# %%
year_2015.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        0
# Engine HP              51
# Engine Cylinders        8
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         5
# Market Category      1324
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
missing_fillna = price_data.fillna({'Engine HP': price_data['Engine HP'].mean()})

# %%
mean_hp_before = price_data['Engine HP'].mean()

# %%
mean_hp_after = missing_fillna['Engine HP'].mean()

# %%
print(round(mean_hp_before))
print(round(mean_hp_after))
# Out:
# 249
# 249

# %%
price_data.nunique()
# Out:
# Make                   48
# Model                 915
# Year                   28
# Engine Fuel Type       10
# Engine HP             356
# Engine Cylinders        9
# Transmission Type       5
# Driven_Wheels           4
# Number of Doors         3
# Market Category        71
# Vehicle Size            3
# Vehicle Style          16
# highway MPG            59
# city mpg               69
# Popularity             48
# MSRP                 6049
# dtype: int64

# %%
all_rolls_roys = price_data[price_data["Make"].str.contains('Rolls-Royce')]

# %%
all_rolls_roys.head()
# Out:
#              Make            Model  Year             Engine Fuel Type  \
# 2921  Rolls-Royce         Corniche  2001  premium unleaded (required)
# 3505  Rolls-Royce             Dawn  2016  premium unleaded (required)
# 5275  Rolls-Royce  Ghost Series II  2015  premium unleaded (required)
# 5276  Rolls-Royce  Ghost Series II  2015  premium unleaded (required)
# 5277  Rolls-Royce  Ghost Series II  2016  premium unleaded (required)
#
#       Engine HP  Engine Cylinders Transmission Type     Driven_Wheels  \
# 2921      325.0               8.0         AUTOMATIC  rear wheel drive
# 3505      563.0              12.0         AUTOMATIC  rear wheel drive
# 5275      563.0              12.0         AUTOMATIC  rear wheel drive
# 5276      563.0              12.0         AUTOMATIC  rear wheel drive
# 5277      563.0              12.0         AUTOMATIC  rear wheel drive
#
#       Number of Doors                 Market Category Vehicle Size  \
# ...

# %%
all_rolls_roys.shape
# Out:
# (31, 16)

# %%
all_rolls_roys.drop_duplicates()
# Out:
#               Make                   Model  Year             Engine Fuel Type  \
# 2921   Rolls-Royce                Corniche  2001  premium unleaded (required)
# 3505   Rolls-Royce                    Dawn  2016  premium unleaded (required)
# 5275   Rolls-Royce         Ghost Series II  2015  premium unleaded (required)
# 5276   Rolls-Royce         Ghost Series II  2015  premium unleaded (required)
# 5277   Rolls-Royce         Ghost Series II  2016  premium unleaded (required)
# 5278   Rolls-Royce         Ghost Series II  2016  premium unleaded (required)
# 5279   Rolls-Royce                   Ghost  2012  premium unleaded (required)
# 5280   Rolls-Royce                   Ghost  2012  premium unleaded (required)
# 5281   Rolls-Royce                   Ghost  2013  premium unleaded (required)
# 5282   Rolls-Royce                   Ghost  2013  premium unleaded (required)
# 5283   Rolls-Royce                   Ghost  2014  premium unleaded (required)
# ...

# %%
all_rolls_roys.shape
# Out:
# (31, 16)

# %%
cols = ["Engine HP", "Engine Cylinders", "highway MPG"]

# %%
all_rolls_roys_dup = all_rolls_roys[cols]

# %%
all_rolls_roys_dup.shape
# Out:
# (31, 3)

# %%
all_rolls_roys_dup1 = all_rolls_roys_dup.drop_duplicates()

# %%
all_rolls_roys_dup1.shape
# Out:
# (7, 3)

# %%
all_rolls_roys_dup1.head(7)
# Out:
#        Engine HP  Engine Cylinders  highway MPG
# 2921       325.0               8.0           15
# 3505       563.0              12.0           19
# 5275       563.0              12.0           21
# 5279       563.0              12.0           20
# 7443       322.0              12.0           15
# 7553       453.0              12.0           19
# 11448      624.0              12.0           21

# %%
X = all_rolls_roys_dup1.to_numpy()

# %%
X.shape
# Out:
# (7, 3)

# %%
X
# Out:
# array([[325.,   8.,  15.],
#        [563.,  12.,  19.],
#        [563.,  12.,  21.],
#        [563.,  12.,  20.],
#        [322.,  12.,  15.],
#        [453.,  12.,  19.],
#        [624.,  12.,  21.]])

# %%
trans = X.T

# %%
trans
# Out:
# array([[325., 563., 563., 563., 322., 453., 624.],
#        [  8.,  12.,  12.,  12.,  12.,  12.,  12.],
#        [ 15.,  19.,  21.,  20.,  15.,  19.,  21.]])

# %%
XTX = np.dot(trans,X)

# %%
XTX
# Out:
# array([[1.754801e+06, 3.965600e+04, 6.519600e+04],
#        [3.965600e+04, 9.280000e+02, 1.500000e+03],
#        [6.519600e+04, 1.500000e+03, 2.454000e+03]])

# %%
XTX_inv = np.linalg.inv(XTX)

# %%
XTX_inv
# Out:
# array([[ 5.17815728e-05,  9.06587044e-04, -1.92984188e-03],
#        [ 9.06587044e-04,  1.05723058e-01, -8.87084092e-02],
#        [-1.92984188e-03, -8.87084092e-02,  1.05900809e-01]])

# %%
total = np.sum(XTX_inv)

# %%
print(total)
# Out:
# 0.032212320677486125

# %%
total1 = np.sum(XTX)

# %%
total1
# Out:
# 1970887.0

# %%
y = np.array([1000, 1100, 900, 1200, 1000, 850, 1300])

# %%
trans_inv = np.dot(XTX_inv,trans)

# %%
trans_inv
# Out:
# array([[-0.00486592,  0.00336507, -0.00049461,  0.00143523, -0.00139492,
#         -0.0023309 ,  0.00266407],
#        [-0.19020088,  0.09362543, -0.08379139,  0.00491702,  0.22997159,
#         -0.00609915, -0.02848958],
#        [ 0.25164625, -0.13888652,  0.0729151 , -0.03298571, -0.09739786,
#          0.07339609, -0.04480526]])

# %%
w = np.dot(trans_inv,y)

# %%
w
# Out:
# array([ 0.19989598, 31.02612262, 31.65378877])
